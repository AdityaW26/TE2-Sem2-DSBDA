# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt;

# %%
import seaborn as sns;

# %%
df = sns.load_dataset('titanic')

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['age'].fillna(df['age'].mean(),inplace = True)

# %%
df['embarked'].fillna(df['embarked'].mode()[0],inplace = True)

# %%
df['embark_town'].fillna(df['embark_town'].mode()[0],inplace = True)

# %%
df = df.drop(['deck'],axis = 1)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
sns.boxplot(x='class',y='age',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
sns.boxplot(x='sex',y='fare',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fare'>

# %%
sns.swarmplot(x='class',y='age',data=df)
# Out:
# /home/pict/.local/lib/python3.6/site-packages/seaborn/categorical.py:1296: UserWarning: 11.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/pict/.local/lib/python3.6/site-packages/seaborn/categorical.py:1296: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/pict/.local/lib/python3.6/site-packages/seaborn/categorical.py:1296: UserWarning: 43.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
plt.figure(figsize=(8,8))
sns.barplot(x="sex", y="survived", hue="class", data=df)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.stripplot(x="fare", y="age", data = df)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.stripplot(x="sex", y="fare", data = df)
plt.show()

# %%
sns.violinplot(x="survived", y="age", hue='sex', data = df)
plt.show()

# %%
#df_train["Age"].fillna(df_train.groupby("Pclass")["Age"].transform("median"), inplace=True)

# %%
sns.barplot(x = 'sex', y = 'survived', hue = 'class', data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
sns.barplot(x = 'sex', y = 'fare', hue = 'class', data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fare'>
