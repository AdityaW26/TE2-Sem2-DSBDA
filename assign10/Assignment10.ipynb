# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

# %%
df= pd.read_csv("iris.csv")

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.tail()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
df.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
df.hist(column="sepal.length")
# Out:
# array([[<AxesSubplot:title={'center':'sepal.length'}>]], dtype=object)

# %%
df.hist(column="sepal.width")
# Out:
# array([[<AxesSubplot:title={'center':'sepal.width'}>]], dtype=object)

# %%
df.hist(column="petal.length")
# Out:
# array([[<AxesSubplot:title={'center':'petal.length'}>]], dtype=object)

# %%
df.hist(column="petal.width")
# Out:
# array([[<AxesSubplot:title={'center':'petal.width'}>]], dtype=object)

# %%
df.groupby('variety').size().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='variety'>

# %%
df.hist(by ='variety', column =['petal.width'], grid = False)
# Out:
# array([[<AxesSubplot:title={'center':'Setosa'}>,
#         <AxesSubplot:title={'center':'Versicolor'}>],
#        [<AxesSubplot:title={'center':'Virginica'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df.boxplot(by ='variety', column =['petal.width'], grid = False)
# Out:
# <AxesSubplot:title={'center':'petal.width'}, xlabel='variety'>

# %%
df.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
df.boxplot(by ='variety', column =['sepal.length'], grid = False)
df.boxplot(by ='variety', column =['sepal.width'], grid = False)
df.boxplot(by ='variety', column =['petal.length'], grid = False)
df.boxplot(by ='variety', column =['petal.width'], grid = False)
# Out:
# <AxesSubplot:title={'center':'petal.width'}, xlabel='variety'>

# %%
df.boxplot(by ='variety', column =['sepal.length'], grid = False,showfliers=False)
df.boxplot(by ='variety', column =['sepal.width'], grid = False,showfliers=False)
df.boxplot(by ='variety', column =['petal.length'], grid = False,showfliers=False)
df.boxplot(by ='variety', column =['petal.width'], grid = False,showfliers=False)
# Out:
# <AxesSubplot:title={'center':'petal.width'}, xlabel='variety'>

# %%
df.boxplot(by ='variety', column =['sepal.length'], grid = False, showfliers=False)
# Out:
# <AxesSubplot:title={'center':'sepal.length'}, xlabel='variety'>
